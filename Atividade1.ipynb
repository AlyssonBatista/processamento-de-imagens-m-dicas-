# %% [markdown]
# <a href="https://colab.research.google.com/github/AlyssonBatista/processamento-de-imagens-m-dicas-/blob/main/Atividade1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow # Função para o colab exibir imagens do OpenCV
import copy
from PIL import Image

from PIL import Imag
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import Image

# %%
imgGrey = cv2.imread('nebulosa.jpg',0)
cv2_imshow(imgGrey)
# Out:
# <PIL.Image.Image image mode=L size=75x75 at 0x7FD1144F8050>

# %%
 
cb_img = cv2.imread("nebulosa.jpg",0)
 
print(cb_img)
# Out:
# [[ 6  7  6 ...  6  6  6]
#  [ 4  5  7 ...  6  6  6]
#  [ 8  4  3 ...  6  6  6]
#  ...
#  [ 5  5  5 ... 10 18  7]
#  [ 5  5  5 ... 11 18  9]
#  [ 5  5  5 ...  3  8  2]]

# %%
img_NZ_bgr = cv2.imread("nebulosa.jpg",cv2.IMREAD_COLOR)
b,g,r = cv2.split(img_NZ_bgr)

plt.figure(figsize=[20,5])
plt.subplot(141);plt.imshow(r,cmap='gray');plt.title("Red Channel");
plt.subplot(142);plt.imshow(g,cmap='gray');plt.title("Green Channel");
plt.subplot(143);plt.imshow(b,cmap='gray');plt.title("Blue Channel");

imgMerged = cv2.merge((b,g,r))

plt.subplot(144);plt.imshow(imgMerged[:,:,::-1]);plt.title("Merged Output");

# %%
#Componentes de cores da imagem, apresentar as três componentes de cores da imagem

img_2 = cv2.imread('/content/drive/MyDrive/PIM_imagens/torre_eiffel.webp')


# Deixa apenas o canal Azul
img_only_blue = copy.copy(img_NZ_bgr)

#img_only_blue[:,:,0] = 0
img_only_blue[:,:,1] = 0
img_only_blue[:,:,2] = 0


# Deixa apenas o canal VERDE
img_only_green = copy.copy(img_NZ_bgr)

img_only_green[:,:,0] = 0
#img_only_green[:,:,1] = 0
img_only_green[:,:,2] = 0

# Deixa apenas o canal VERMELHO
img_only_red = copy.copy(img_NZ_bgr)

img_only_red[:,:,0] = 0
img_only_red[:,:,1] = 0
#img_only_red[:,:,2] = 0

# Exibe as imagens
cv2_imshow(img_NZ_bgr )
cv2_imshow(img_only_blue)
cv2_imshow(img_only_green) 
cv2_imshow(img_only_red)
# Out:
# <PIL.Image.Image image mode=RGB size=75x75 at 0x7FD113AF1690>
# <PIL.Image.Image image mode=RGB size=75x75 at 0x7FD113AD5950>
# <PIL.Image.Image image mode=RGB size=75x75 at 0x7FD113AF10D0>
# <PIL.Image.Image image mode=RGB size=75x75 at 0x7FD114BD3050>
